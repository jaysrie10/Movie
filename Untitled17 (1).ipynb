# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
# Load dataset
df = pd.read_csv(r"C:\Users\Seyed Dhilbar S\Downloads\heart_disease_uci.csv")

# %%
# Display data
print(df.head())
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
# Handle missing values
df = df.dropna()

# %%
# Features and target
X = df.drop("num", axis=1)
y = df["num"]

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
# Normalize data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
# Model
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Predictions
y_pred = model.predict(X_test)

# %%
# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6
#               precision    recall  f1-score   support
#
#            0       0.79      0.97      0.87        35
#            1       0.17      0.08      0.11        13
#            2       0.20      0.20      0.20         5
#            3       0.00      0.00      0.00         4
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.60        60
#    macro avg       0.23      0.25      0.24        60
# weighted avg       0.51      0.60      0.55        60
# C:\Users\Seyed Dhilbar S\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
import matplotlib.pyplot as plt

importance = model.feature_importances_
features = X.columns

plt.barh(features, importance)
plt.xlabel("Importance")
plt.title("Feature Importance")
plt.show()

# %%
# !pip install shap

# %%
import shap

explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X)

# %%
# Drop personal identifiers
df = df.drop(columns=['name', 'patient_id'], errors='ignore')

# %%
import numpy as np
import hashlib

# Create fake patient ID
df['patient_id'] = np.arange(len(df))

# Anonymize it
def anonymize(text):
    return hashlib.sha256(str(text).encode()).hexdigest()

df['patient_id'] = df['patient_id'].apply(anonymize)

# %%
# Show only limited rows
print(df.head())

# Avoid printing full dataset in production
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num                                         patient_id
# 0       fixed defect    0  5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...
# ...

# %%
print(df['sex'].value_counts())
# Out:
# sex
# Male      203
# Female     96
# Name: count, dtype: int64

# %%
# Compare predictions across gender
import pandas as pd

results = pd.DataFrame({'sex': df['sex'], 'prediction': model.predict(X_scaled)})
print(results.groupby('sex')['prediction'].mean())
# Out:
# sex
# Female    0.520833
# Male      1.083744
# Name: prediction, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
import pandas as pd

importance = model.feature_importances_
feature_names = X.columns

feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importance
}).sort_values(by='Importance', ascending=False)

print(feature_importance_df)
# Out:
#                      Feature  Importance
# 4                     thalch    0.132945
# 5                    oldpeak    0.103032
# 0                         id    0.098262
# 3                       chol    0.098024
# 6                         ca    0.094181
# 1                        age    0.087762
# 2                   trestbps    0.086285
# 19               thal_normal    0.055987
# 16                exang_True    0.047629
# 20    thal_reversable defect    0.037857
# 18           slope_upsloping    0.026139
# 7                   sex_Male    0.025397
# 17                slope_flat    0.023563
# 14            restecg_normal    0.023090
# 11            cp_non-anginal    0.021933
# 13                  fbs_True    0.016315
# 12         cp_typical angina    0.011068
# 10        cp_atypical angina    0.007989
# 15  restecg_st-t abnormality    0.001154
# 9      dataset_VA Long Beach    0.000701
# 8            dataset_Hungary    0.000688
